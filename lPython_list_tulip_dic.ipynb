# %%
#Python is case sensative lanaguage
#return is keyword and not Return

#Do not use keyword as  identifiers in programming

 # Pyhotn is dynamic lanaguage which means you dont need to declare data type of varible 


#List and Dictionari are matuable where as tulp is not mutable

list_name = [1,2,3,5,6,"Apple","Banana"]
print( list_name)
# Out:
# [1, 2, 3, 5, 6, 'Apple', 'Banana']

# %%
# Indentaion is important for loops to work in python

x=10
if x>5:
    print(f"Value of x is {x} it is greater that 5")
# Out:
# Value of x is 10 it is greater that 5

# %%
fruit =["Banana", "Apple", "Kiwi"] # This is list

print(f"This is list of fruits {fruit}")


tuple_fruits = (1,2,3,"Grapes","Berry")
print(f"This is tuple {tuple_fruits}")
# Out:
# This is list of fruits ['Banana', 'Apple', 'Kiwi']
# This is tuple (1, 2, 3, 'Grapes', 'Berry')
